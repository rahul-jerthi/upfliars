# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cust_satisfaction.csv")

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
# df.dropna(inplace=True). # drop rows with null values
df.isnull().sum()

df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103594 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103594 non-null  object
#  1   Customer Type               103594 non-null  object
#  2   Type of Travel              103594 non-null  object
#  3   Class                       103594 non-null  object
#  4   satisfaction                103594 non-null  object
#  5   Age                         103594 non-null  int64
#  6   Flight Distance             103594 non-null  int64
#  7   Inflight entertainment      103594 non-null  int64
#  8   Baggage handling            103594 non-null  int64
#  9   Cleanliness                 103594 non-null  int64
#  10  Departure Delay in Minutes  103594 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 10.3+ MB

# %%
df.head(5)
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0

# %% [markdown]
# # Checking Duplicates ND Removing it

# %%
df.duplicated().sum()
# Out:
# 172

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Converting text into int ---> for model understanding

# %%
df["Gender"] = df["Gender"].map({"Male":0, "Female":1})
df["Customer Type"] = df["Customer Type"].map({"Loyal Customer":0, "disloyal Customer":1})
df["Type of Travel"] = df["Type of Travel"].map({"Personal Travel":0, "Business travel":1})
df["Class"] = df["Class"].map({"Eco":0, "Business":1, "Eco Plus":2})
df["satisfaction"] = df["satisfaction"].map({"neutral or dissatisfied":0, "satisfied":1})

# %%
df["Customer Type"].value_counts()
# Out:
# Customer Type
# 0    84517
# 1    18905
# Name: count, dtype: int64

# %%
df["Class"].value_counts()
# df.head(2)
# Out:
# Class
# 1    49423
# 0    46532
# 2     7467
# Name: count, dtype: int64

# %%
df.head(15)
# Out:
#     Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0        0              0               0      2             0   13
# 1        0              1               1      1             0   25
# 2        1              0               1      1             1   26
# 3        1              0               1      1             0   25
# 4        0              0               1      1             1   61
# 5        1              0               0      0             0   26
# 6        0              0               0      0             0   47
# 7        1              0               1      1             1   52
# 8        1              0               1      1             0   41
# 9        0              1               1      0             0   20
# 10       1              1               1      0             0   24
# 11       1              0               0      2             0   12
# 12       0              0               1      0             0   53
# 13       0              0               0      0             1   33
# 14       1              0               0      0             0   26
#
#     Flight Distance  Inflight entertainment  Baggage handling  Cleanliness  \
# 0               460                       5                 4            5
# 1               235                       1                 3            1
# 2              1142                       5                 4            5
# 3               562                       2                 3            2
# 4               214                       3                 4            3
# 5              1180                       1                 4            1
# 6              1276                       2                 4            2
# 7              2035                       5                 5            4
# 8               853                       1                 1            2
# 9              1061                       2                 4            2
# 10             1182                       2                 5            2
# 11              308                       1                 5            1
# 12              834                       1                 3            1
# 13              946                       4                 2            4
# 14              453                       2                 2            2
#
#     Departure Delay in Minutes  Arrival Delay in Minutes
# 0                           25                      18.0
# 1                            1                       6.0
# 2                            0                       0.0
# 3                           11                       9.0
# 4                            0                       0.0
# 5                            0                       0.0
# 6                            9                      23.0
# 7                            4                       0.0
# 8                            0                       0.0
# 9                            0                       0.0
# 10                           0                       0.0
# 11                           0                       0.0
# 12                          28                       8.0
# 13                           0                       0.0
# 14                          43                      35.0

# %% [markdown]
# # Handling the inbalance data

# %%
Loyal_customer = df[df["Customer Type"] == 0].loc[0:20000]
Disloyal_customer = df[df["Customer Type"] == 1]

# %%
balance_df = pd.concat([Loyal_customer, Disloyal_customer], axis=0)
balance_df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            0              0               0      2             0   13
# 2            1              0               1      1             1   26
# 3            1              0               1      1             0   25
# 4            0              0               1      1             1   61
# 5            1              0               0      0             0   26
# ...        ...            ...             ...    ...           ...  ...
# 103892       1              1               1      1             0   37
# 103895       1              1               1      0             0   24
# 103899       1              1               1      0             0   23
# 103901       0              1               1      1             0   30
# 103902       1              1               1      0             0   22
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# 0                   460                       5                 4
# 2                  1142                       5                 4
# 3                   562                       2                 3
# 4                   214                       3                 4
# 5                  1180                       1                 4
# ...                 ...                     ...               ...
# 103892              596                       3                 3
# 103895             1055                       1                 5
# 103899              192                       2                 4
# 103901             1995                       4                 4
# 103902             1000                       1                 1
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0                 5                          25                      18.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 4                 3                           0                       0.0
# 5                 1                           0                       0.0
# ...             ...                         ...                       ...
# 103892            3                         110                     121.0
# 103895            1                          13                      10.0
# 103899            2                           3                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
#
# [35239 rows x 12 columns]

# %% [markdown]
# # Data dividing X and Y

# %%
x = balance_df.drop("Customer Type", axis=1)
y = balance_df["Customer Type"]

# %% [markdown]
# # data spliting and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state= 42)

# %% [markdown]
# # normalise -- data range

# %%
from sklearn.preprocessing import StandardScaler
sd = StandardScaler()
x_train_scaled = sd.fit_transform(x_train)
x_test_scaled = sd.transform(x_test)

# %% [markdown]
# # ANN Architecture Designing

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# ann model definfing
model = Sequential()

#input layer
model.add(Dense(68,activation="relu",input_dim = x_train.shape[1]))

#hidden layer
model.add(Dense(32,activation="relu"))
model.add(Dense(24,activation="relu"))
model.add(Dense(12,activation="relu"))

#output Layer
model.add(Dense(1,activation="sigmoid"))

#model compile
model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])


model.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 68)             │           816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 24)             │           792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 12)             │           300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,129 (16.13 KB)
#  Trainable params: 4,129 (16.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train_scaled, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(x_test_scaled, y_test))
# Out:
# Epoch 1/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8704 - loss: 0.3348 - val_accuracy: 0.9091 - val_loss: 0.2329
# Epoch 2/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9066 - loss: 0.2399 - val_accuracy: 0.9129 - val_loss: 0.2281
# Epoch 3/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9130 - loss: 0.2214 - val_accuracy: 0.9150 - val_loss: 0.2200
# Epoch 4/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9156 - loss: 0.2230 - val_accuracy: 0.9157 - val_loss: 0.2179
# Epoch 5/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9225 - loss: 0.2076 - val_accuracy: 0.9191 - val_loss: 0.2142
# Epoch 6/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9221 - loss: 0.2075 - val_accuracy: 0.9208 - val_loss: 0.2103
# Epoch 7/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9192 - loss: 0.2082 - val_accuracy: 0.9210 - val_loss: 0.2132
# Epoch 8/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9221 - loss: 0.2032 - val_accuracy: 0.9211 - val_loss: 0.2080
# Epoch 9/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9248 - loss: 0.1955 - val_accuracy: 0.9221 - val_loss: 0.2062
# Epoch 10/10
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9238 - loss: 0.2011 - val_accuracy: 0.9225 - val_loss: 0.2077
